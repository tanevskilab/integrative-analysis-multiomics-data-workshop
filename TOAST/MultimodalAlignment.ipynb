# %%
import numpy as np
import pandas as pd
from spatial_OT.OT import *
from spatial_OT.utils import *
from scipy.spatial import distance
import numpy as np
import scanpy as sc
import anndata as ad
import ot
import matplotlib.pyplot as plt
from sklearn.metrics import adjusted_rand_score
import warnings
import time
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
warnings.filterwarnings('ignore')
# Out:
# /Users/sebgoti/Documents/PhD/integrative-analysis-multiomics-data-workshop/.pixi/envs/toast/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
'''
An Optimal-Transport based approach for quantifying the spatiotemporal growth of tissues.
'''
import numpy as np
import scipy
import matplotlib.pyplot as plt
import torch

def Cost(f, g, Grad, epsilon, device='cpu'):
    '''
    A matrix which is using for the broadcasted log-domain log-sum-exp trick-based updates.
    ------Parameters------
    f: torch.tensor (N1)
        First dual variable of semi-unbalanced Sinkhorn
    g: torch.tensor (N2)
        Second dual variable of semi-unbalanced Sinkhorn
    Grad: torch.tensor (N1 x N2)
        A collection of terms in our gradient for the update
    epsilon: float
        Entropic regularization for Sinkhorn
    device: 'str'
        Device tensors placed on
    '''
    return -( Grad - torch.outer(f, torch.ones(Grad.size(dim=1), device=device)) - torch.outer(torch.ones(Grad.size(dim=0), device=device), g) ) / epsilon

def normalize_M(M, C, N1, _ord='fro'):
    '''
    A function to return normalization constants for the gradient involving the merged feature-spatial matrix,
    which is normalized by a factor related to the interslice feature cost C.
    ------Parameters------
    M: torch.tensor (N x N)
        A symmetric matrix with positive entries (i.e. distance matrix, merged feature-spatial matrix)
    C: torch.tensor (N x M) or (M x N)
        Matrix of pairwise feature distances between slice 1 and 2
    N1: int
        Number of spots in first slice
    '''
    return (torch.linalg.norm(C, ord=_ord)**(1/2) / torch.linalg.norm(M, ord=_ord)) * (N1 )**(1/2)

def LogSinkhorn_iteration(C, D1, D2, C1, C2, Pi_0=None, alpha=0.2, beta=0.5, gamma=50, epsilon=1e-1, max_iter=100, balanced=False, device='cpu', dtype=torch.float64, override_EDM=False, override_FDM=False):
    '''
    Sinkhorn algorithm for the balanced/partially unbalanced case, with log-domain stabilization.
    ------Parameters------
    C: torch.tensor (N1 x N2)
        A matrix of pairwise feature distances between transcript vectors in slice 1 and slice 2 (interslice).
    D1: torch.tensor (N1 x N1)
        A matrix of pairwise Euclidean distances between points in slice 1.
    D2: torch.tensor (N2 x N2)
        A matrix of pairwise Euclidean distances between points in slice 2.
    C1: torch.tensor (N1 x N1)
        A matrix of pairwise feature distances between transcript vectors in slice 1 (intraslice).
    C2: torch.tensor (N2 x N2)
        A matrix of pairwise feature distances between transcript vectors in slice 2 (intraslice).
    Pi_0: torch.tensor (N1 x N2)
        An initialization for the alignment matrix Pi. Should respect marginals of semi-unbalanced or balanced.
    alpha: float
        A balance parameter between the interslice feature term of the objective and the merged feature-spatial term.
    beta: float
        A balance parameter between the GW (quartet) term and the triplet term of the merged feature-spatial term.
    gamma: float
        A hyperparameter controlling the strength of the KL-divergence term in the objective.
    epsilon: float
        A hyperparameter controlling the strength of the entropic regularization in the Sinkhorn algorithm.
    max_iter: int
        The maximal number of iterations DeST-OT is run.
    balanced: bool
        Boolean for whether to default to a balanced OT or to use DeST-OT's semi-unbalanced routine. Default set to False.
    device: str
        Device that torch tensors are placed on. Using GPU/'cuda' is much faster.
    dtype: torch.type
        The default datatype that the alignment and other tensors are in. Ideally torch.float64 or torch.float32
    override_EDM: bool
        Whether to override the merged feature-spatial matrix with a standard Euclidean distance matrix.
    override_FDM:
        Whether to override the merged feature-spatial matrix with an intraslice feature distance matrix.
    '''
    
    N1, N2 = C.size(dim=0), C.size(dim=1)
    
    M1 = D1 * C1
    M2 = D2 * C2
    
    if override_EDM:
        # Override fused matrix with standard EDM
        M1 = D1
        M2 = D2
    elif override_FDM:
        # Override fused matrix with feature distance matrix
        M1 = C1
        M2 = C2
    
    # Normalizing constants
    p1, p2 = normalize_M(M1, C, N1, _ord='fro'), \
                            normalize_M(M2, C, N1, _ord='fro')
    r2, r1 = torch.linalg.norm(C, ord='fro')/torch.linalg.norm(M2**2, ord='fro') * (N1**1/2), \
                            torch.linalg.norm(C, ord='fro')/torch.linalg.norm(M1**2, ord='fro') * (N1 / N2**(1/2))
    
    k = 0
    stationarity_gap = torch.inf
    
    # These are the same for this synthetic data-- change dimensions when we get there
    one_N1 = torch.ones((N1), device=device, dtype=dtype)
    one_N2 = torch.ones((N2), device=device, dtype=dtype)
    
    g1 = one_N1 / N1
    
    if balanced:
        g2 = one_N2 / N2
    else:
        g2 = one_N2 / N1
    
    log_g1 = torch.log(g1)
    log_g2 = torch.log(g2)
    
    if Pi_0 is None:
        # Will converge to partially balanced marginal
        Pi_0 = torch.outer(g1, g2).to(device)
    
    Pi_k = Pi_0
    
    f_k = torch.zeros((N1), device=device)
    g_k = torch.zeros((N2), device=device)
    
    errs = []
    
    # unbalanced coefficient
    ubc = gamma/(gamma + epsilon)
    
    grad = torch.inf
    while k < max_iter:
        
        # Offering the user the option to choose their energy-regularization
        dist_orig = r1*(M1**2 @ Pi_k) + r2*(Pi_k @ M2**2)
        
        if balanced:
            dist_GW = -2 * ((p1*M1) @ Pi_k @ (p2*M2)) 
        else:
            dist_GW = -2*((p1*M1) @ Pi_k @ (p2*M2).T) + (p1*M1)**2 @ Pi_k @ torch.ones((N2, N2), device=device, dtype=dtype)
        
        grad = (1-alpha)*C + alpha*(beta*dist_orig + (1-beta)*dist_GW)
        
        if balanced:
            f_k = f_k + epsilon*(log_g1 - torch.logsumexp(Cost(f_k, g_k, grad, epsilon, device=device), axis=1))
            g_k = g_k + epsilon*(log_g2 - torch.logsumexp(Cost(f_k, g_k, grad, epsilon, device=device), axis=0))
        elif balanced is False:
            # Partially unbalanced coefficient used on one of the dual variables
            f_k = ubc*(f_k + epsilon*(log_g1 - torch.logsumexp(Cost(f_k, g_k, grad, epsilon, device=device), axis=1)) )
            g_k = g_k + epsilon*(log_g2 - torch.logsumexp(Cost(f_k, g_k, grad, epsilon, device=device), axis=0))
        
        Pi = torch.exp(Cost(f_k, g_k, grad, epsilon, device=device))
        # Checking whether we're approaching a fixed point
        stationarity_gap = torch.linalg.norm(Pi_k - Pi, ord='fro')
        Pi_k = Pi
        
        k+=1
        errs.append(stationarity_gap)
    
    xi = (Pi_k @ one_N2 - g1)
    
    return xi, Pi_k, errs

import torch
import anndata as ad
import scanpy as sc
import numpy as np
from scipy.spatial import distance
from pynvml import *


def intersect(lst1, lst2): 
    """
    param: lst1 - list
    param: lst2 - list
    
    return: list of common elements
    """
    temp = set(lst2)
    lst3 = [value for value in lst1 if value in temp]
    return lst3 

"""
This function to select a GPU is from the scSLAT package.
"""
def get_free_gpu() -> int:
    """
    Get index of GPU with least memory usage
    
    Ref
    ----------
    https://stackoverflow.com/questions/58216000/get-total-amount-of-free-gpu-memory-and-available-using-pytorch
    """
    nvmlInit()
    index = 0
    max = 0
    for i in range(torch.cuda.device_count()):
        h = nvmlDeviceGetHandleByIndex(i)
        info = nvmlDeviceGetMemoryInfo(h)
        index = i if info.free > max else index
        max = info.free if info.free > max else max
        
    # seed = np.random.randint(1000)
    # os.system(f'nvidia-smi -q -d Memory |grep Used > gpu-{str(seed)}.tmp')
    # memory_available = [int(x.split()[2]) for x in open('gpu.tmp', 'r').readlines()]
    # os.system(f'rm gpu-{str(seed)}.tmp')
    # print(memory_available)
    return index

def xi_to_growth_rate(xi, t1=0, t2=1, normalize_xi=True):
    '''
    Returns a differential growth rate given the growth vector xi.
    
    Parameters:
    xi: numpy array (N1)
        Growth vector quantifying the raw mass-flux
    t1: float
        First observation timepoint
    t2: float
        Second observation timepoint
    normalize_xi: bool
        True if xi normalized to number of cells units (this is the default output of align, using the same flag "normalize_xi"),
        False if xi directly computed from Pi without renormalization.
    '''
    N1 = xi.shape[0]
    if normalize_xi is False:
        Js = np.log(N1*xi + 1) / (t2 - t1)
    else:
        Js = np.log(xi + 1) / (t2 - t1)
    # Returning a proper growth-rate given mass-flux xi
    return Js

def align(slice_t1, slice_t2, alpha=0.2, gamma=50, epsilon=1e-1, max_iter=100, balanced=False, use_gpu=True, normalize_xi=True, check_convergence=False):
    """
    Run DeST-OT

    Parameters:
    slice_t1: AnnData object
        The AnnData object of the first slice, with .obsm['spatial'] field storing the spatial coordinates
    slice_t2: AnnData object
        The AnnData object of the second slice, with .obsm['spatial'] field storing the spatial coordinates
    alpha: float
        A balance parameter between the interslice feature term of the objective and the merged feature-spatial term. Default is 0.2.
    gamma: float
        A hyperparameter controlling the strength of the KL-divergence term in the objective. Default is 50.
    epsilon: float
        A hyperparameter controlling the strength of the entropic regularization in the Sinkhorn algorithm. Default is 0.1.
    max_iter: int
        The maximal number of iterations DeST-OT is run. Default is 100.
    balanced: bool
        Boolean for whether to default to a balanced OT or to use DeST-OT's semi-unbalanced routine. Default set to False.
    use_gpu: bool
        Boolean for whether to use GPU. Default is True.
    normalize_xi: bool
        Boolean for whether to normalize the growth vector xi to the unit of number of spots. If True, each entry in xi will be in the unit of number of spots, e.g. xi_i = 1 means spots i will grow into two spots in the next timepoint. Default is False.
        Note: set to False when use the output xi to compute the growth distortion metric.
    check_convergence: bool
        Boolean for whether to return the stationarity gap with respect to Pi for each iteration.

    Returns:
    Pi: numpy array of shape (N1 x N2)
        The alignment matrix
    xi: numpy array of shape (N1)
        The growth vector
    errs: list of size (max_iter)
        If check_convergence is True, return a list of stationarity gaps for each iterations. Used for checking the convergence of Pi.
    """
    X = slice_t1.X.toarray()
    Y = slice_t2.X.toarray()
    
    C = distance.cdist(X, Y)
    C1 = distance.cdist(X, X)
    C2 = distance.cdist(Y, Y)
    # Calculate spatial distances
    D1 = distance.cdist(slice_t1.obsm['spatial'], slice_t1.obsm['spatial'])
    D2 = distance.cdist(slice_t2.obsm['spatial'], slice_t2.obsm['spatial'])

    # Pytorch
    if use_gpu:
        gpu_index = get_free_gpu()
        device = torch.device(f'cuda:{gpu_index}' if torch.cuda.is_available() else 'cpu')
    else:
        device='cpu'
    C = torch.from_numpy(C).to(device)
    C1 = torch.from_numpy(C1).to(device)
    C2 = torch.from_numpy(C2).to(device)
    D1 = torch.from_numpy(D1).to(device)
    D2 = torch.from_numpy(D2).to(device)

    # Run DeST-OT
    xi, Pi, errs = LogSinkhorn_iteration(C, D1, D2, C1, C2, alpha=alpha, gamma=gamma, epsilon=epsilon, max_iter=max_iter, balanced=balanced, device=device)
    Pi = Pi.cpu().detach().numpy()
    xi = xi.cpu().detach().numpy()

    lseed=0
    rseed=1
    np.random.seed(lseed)
    np.random.seed(rseed)
    batch_size=1000
    lidx = np.random.randint(0, X.shape[0], size=batch_size)
    np.random.seed(rseed)
    ridx = np.random.randint(0, Y.shape[0], size=batch_size)
    C = distance.cdist(X[lidx], Y[ridx], metric="euclidean")
    Pi_sub = Pi[np.ix_(lidx, ridx)] 
    destot_dist = C * Pi_sub
    sum_destot = np.sum(destot_dist)

    if normalize_xi:
        xi = slice_t1.shape[0] * xi
    if check_convergence:
        return Pi, xi, errs, 
    return Pi, xi, sum_destot

import numpy as np
import scanpy as sc
from scipy.spatial import distance
import pandas as pd


def partial_procrustes_analysis(X, Y, pi):
    m = np.sum(pi)
    Z = (X - pi.sum(axis=1).dot(X) * (1.0 / m)).T
    W = (Y - pi.sum(axis=0).dot(Y) * (1.0 / m)).T
    H = W.dot(pi.T.dot(Z.T))
    U, S, Vt = np.linalg.svd(H)
    R = Vt.T.dot(U.T)
    W = R.dot(W)
    return Z.T, W.T


def partial_stack_slices_pairwise(slices, pis):
    assert len(slices) == len(pis) + 1, "'slices' should have length one more than 'pis'. Please double check."
    assert len(slices) > 1, "You should have at least 2 layers."

    new_coor = []
    S1, S2 = partial_procrustes_analysis(slices[0].obsm['spatial'], slices[1].obsm['spatial'], pis[0])
    new_coor.append(S1)
    new_coor.append(S2)
    for i in range(1, len(slices) - 1):
        x, y = partial_procrustes_analysis(new_coor[i], slices[i + 1].obsm['spatial'], pis[i])
        shift = new_coor[i][0,:] - x[0,:]
        y = y + shift
        new_coor.append(y)
    new_slices = []
    for i in range(len(slices)):
        s = slices[i].copy()
        s.obsm['spatial'] = new_coor[i]
        new_slices.append(s)
    return new_slices


def transition_mat(Pi, celltypes1, celltypes2):
    """
    Compute the cell type transition matrix from an alignment matrix Pi (Eq. 10 of the paper)

    Parameters:
    Pi: numpy array of shape (N1, N2)
        The alignment matrix
    celltype1: numpy array of shape N1
        An array of celltypes for each spot on slice t1
    celltype2: numpy array of shape N2
        An array of celltypes for each spot on slice t2

    Return:
    The cell type transition matrix, a numpy array of shape (N_CT, N_CT), where N_CT is the total number of cell types
    """
    celltypes_all = np.unique(np.concatenate((celltypes1,celltypes2), axis=0))
    N_CT = celltypes_all.shape[0]
    
    T = np.zeros((N_CT, N_CT))
    for i in range(N_CT):
        for j in range(N_CT):
            ct_i = celltypes_all[i]
            ct_j = celltypes_all[j]
            mask = np.outer((celltypes1 == ct_i), (celltypes2 == ct_j))
            T[i,j] = np.sum(Pi[mask])
    
    col_sums = T.sum(axis=0)
    non_zero_cols = col_sums != 0
    T[:, non_zero_cols] /= col_sums[non_zero_cols]

    return T


def growth_distortion_metric_helper(xi, celltypes1, celltypes2, T=None):
    '''
    Implementation of the growth distortion metric given the inferred growth vector xi

    Parameters:
    xi: numpy array of shape (N1, N2)
        The growth vector of a spatiotemporal alignment
    celltype1: numpy array of shape N1
        An array of celltypes for each spot on slice t1
    celltype2: numpy array of shape N2
        An array of celltypes for each spot on slice t2
    T: numpy array of shape (N1, N2)
        A cell type transition matrix to compute the growth distortion metric under.

    Returns:
    the growth distortion metric
    '''
    N1 = xi.shape[0]
    if T is not None:
        celltypes = np.unique(np.concatenate((celltypes1,celltypes2), axis=0))
    else:
        celltypes = np.intersect1d(celltypes1, celltypes2)
    
    distortion_measure = 0
    
    N_C = len(celltypes)
    m_t = np.zeros(N_C)
    m_tm1 = np.zeros(N_C)
    
    for p, celltype in np.ndenumerate(celltypes):
        m_t[p] = np.sum(celltypes2 == celltype)
        m_tm1[p] = np.sum(celltypes1 == celltype)
    
    if T is not None:
        # Transition-matrix adjusted assignment of mass-fluxes
        m_t = T @ m_t
    
    # Quantifying the accuracy of matching true baseline growth rates
    growth_rates = np.zeros(celltypes.shape[0])
    for p, celltype in np.ndenumerate(celltypes):
        dmP = (m_t[p] - m_tm1[p])/N1
        growth_rates[p] = gamma_tp = (1/N1)*((m_t[p] - m_tm1[p])/m_tm1[p])
        xi_p = xi[celltypes1 == celltype]
        # Sum of squares error of individual cell growth rates,
        # relative to true cell type specific growth rate.
        distortion_measure += np.sum( (xi_p - gamma_tp * np.ones(xi_p.shape[0]) )**2 )
            
    # print(f'Distortion metric value: {N1*distortion_measure}')
    return N1 * distortion_measure


def growth_distortion_metric(slice_t1, slice_t2, Pi, xi=None, annotation_key="annotation", option="infer_transition"):
    """
    Compute the growth distortion metric given two slices, an alignment matrix Pi, and a growth vector xi

    Parameters:
    slice_t1: AnnData object
        The AnnData object of the first slice, with .obs['annotation'] field storing the cell type of each spot.
    slice_t2: AnnData object
        The AnnData object of slice t2, with .obs['annotation'] field storing the cell type of each spot.
    Pi: numpy array of shape (N1, N2)
        Alignment matrix between slice t1 and slice t2
    xi: numpy array of shape (N1) or NoneType
        The growth vector from the alignment. If not input, then recomputed from Pi.
    annotation_key: String
        The key for the cell-type annotations in the AnnData object
    option: String, one of the following two options
        "no_transition": Assumes no cell type transition, and the growth distortion metric is calculcated based on the intersection of cell types in the two slices
        "infer_transition": Assumes cell type transition during development, and the growth distortion metric is calculated based on the cell type transition matrix of all cell types that minimizes the growth distortion metric for the given Pi (Section 2.3.1 of the paper)

    Returns:
    The growth distortion metric of the given Pi and xi
    """
    if xi is None:
        one_N2 = np.ones(Pi.shape[1])
        g1 = np.ones(Pi.shape[0])/Pi.shape[0]
        xi = (Pi @ one_N2 - g1)
    else:
        pass
    l1, l2 = slice_t1.obs[annotation_key].tolist(), slice_t2.obs[annotation_key].tolist()
    l_merged = l1 + l2
    categorical_labels, celltypes = pd.factorize(l_merged)
    celltypes1 = categorical_labels[:len(l1)]
    celltypes2 = categorical_labels[len(l1):]

    if option == 'no_transition':
        T = None
    elif option == 'infer_transition':
        T = transition_mat(Pi, celltypes1, celltypes2)
    else:
        raise Exception('Invalid Option')
    
    return growth_distortion_metric_helper(xi, celltypes1, celltypes2, T)


def migration_metric(slice_t1, slice_t2, Pi):
    """
    Compute the migration metric given two slices and an aligment matrix Pi

    Parameters:
    slice_t1: AnnData object
        An AnnData object of slice t1, with .obsm['spatial'] field storing the spatial coordinates.
    slice_t2: AnnData object
        An AnnData object of slice t2, with .obsm['spatial'] field storing the spatial coordinates.
    Pi: numpy array of shape (N1 x N2)
        Alignment matrix between slice t1 and slice t2

    Returns:
    The migration metric of Pi
    """
    slice_t1_newcoor_adata, slice_t2_newcoor_adata = partial_stack_slices_pairwise([slice_t1, slice_t2], [Pi])
    
    slice_t1_newcoor = slice_t1_newcoor_adata.obsm['spatial']
    slice_t2_newcoor = slice_t2_newcoor_adata.obsm['spatial']
    
    V = distance.cdist(slice_t2_newcoor, slice_t1_newcoor)
    
    # Handling zero entries in Pi @ 1_n (i.e. spot not mapped at all to next timepoint)
    ma = (Pi @ np.ones(Pi.shape[1])) > 0

    Pi_hat = Pi[ma, :] / (Pi @ np.ones(Pi.shape[1]))[ma][:, None]
    # Pi_hat = pi / (pi @ np.ones(pi.shape[1]))[:, None]
    V = V[:,ma]

    migs = np.einsum('ij,ji->i', Pi_hat, V)
    
    avg_weighted_migration_distance = np.mean(migs)
    return avg_weighted_migration_distance

import numpy as np
import scanpy as sc
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import jensenshannon

def compute_transported_adata_argmax(adata_source, adata_target, transport_matrix):
    """
    Compute transported AnnData object using the argmax method.

    Parameters:
        adata_source (AnnData): Original AnnData before transport.
        adata_target (AnnData): Target AnnData after transport.
        transport_matrix (ndarray): Transport matrix (N_source x N_target).

    Returns:
        AnnData: New AnnData with updated spatial coordinates.
    """
    # Extract spatial coordinates
    spatial_target = adata_target.obsm["spatial"]

    # Find the target index with the highest probability for each source cell
    max_indices = np.argmax(transport_matrix, axis=1)  # Shape: (N_source,)

    # Assign new spatial positions from the most probable target cell
    spatial_transported = spatial_target[max_indices]  # Shape: (N_source, 2)

    # Create a new AnnData object for transported data
    adata_transported = adata_source.copy()
    adata_transported.obsm["spatial"] = spatial_transported  # Update spatial positions

    return adata_transported

def compute_local_cell_type_distribution(adata, k=10):
    """
    Compute the local cell-type distribution for each cell.

    Parameters:
        adata (AnnData): AnnData object with spatial coordinates and cell types.
        k (int): Number of nearest neighbors to consider.

    Returns:
        ndarray: Local cell-type distributions (N_cells x N_cell_types).
    """
    # Extract spatial coordinates and cell types
    spatial_coords = adata.obsm["spatial"]
    cell_types = adata.obs["unsupervised_label"].astype("category").cat.codes.values  # Convert categorical to numerical
    unique_types = np.unique(cell_types)  # Get unique cell type indices
    num_types = len(unique_types)  # Number of unique cell types

    # Compute k-nearest neighbors
    knn = NearestNeighbors(n_neighbors=k).fit(spatial_coords)
    neighbors = knn.kneighbors(spatial_coords, return_distance=False)

    # Compute local cell-type distribution
    local_distributions = np.zeros((spatial_coords.shape[0], num_types))

    for i in range(spatial_coords.shape[0]):
        neighbor_types = cell_types[neighbors[i]]  # Get types of neighbors
        for j, cell_type in enumerate(unique_types):
            local_distributions[i, j] = np.sum(neighbor_types == cell_type) / k  # Normalize

    return local_distributions

def compute_js_divergence_before_after(adata_source, adata_transported, k=5):
    """
    Compute the average Jensen-Shannon (JS) divergence between the local cell-type distributions
    before and after transport.

    Parameters:
        adata_source (AnnData): Original AnnData before transport.
        adata_transported (AnnData): AnnData after transport.
        k (int): Number of nearest neighbors to consider.

    Returns:
        float: Average JS divergence across all cells.
    """
    # Compute local cell-type distributions
    source_distributions = compute_local_cell_type_distribution(adata_source, k)
    transported_distributions = compute_local_cell_type_distribution(adata_transported, k)

    # Compute JS divergence for each cell
    js_divergences = [
        jensenshannon(source_distributions[i], transported_distributions[i])
        for i in range(source_distributions.shape[0])
    ]

    # Return average JS divergence across all cells
    return np.mean(js_divergences)


def compute_accuracy_max_prob(transport_matrix, source_labels, target_labels):

    source_labels = np.asarray(source_labels)
    target_labels = np.asarray(target_labels)

    # Get the target cell index with max probability for each source cell
    max_prob_indices = np.argmax(transport_matrix, axis=1)
    
    # Predicted cell types based on max probability
    predicted_labels = target_labels[max_prob_indices]
    # Compare predicted labels with source labels
    correct_predictions = (source_labels == predicted_labels)
    
    # Compute accuracy
    accuracy = correct_predictions.mean()
    
    return accuracy

# %%
k = 5
alpha = 0.5  
epsilon = 0.1  

protein = sc.read_h5ad("/Users/sebgoti/Documents/PhD/TOAST_data/rna.h5ad")
sc.settings.set_figure_params(dpi_save=250)
sc.pl.embedding(
    protein,
    basis="spatial",
    color="unsupervised_label",
    title="RNA leiden",
    s=0.8,
    save="_protein_leiden.pdf"   
)
# Out:
# WARNING: saving figure to file figures/spatial_protein_leiden.pdf

# %%
rna = sc.read_h5ad("/Users/sebgoti/Documents/PhD/TOAST_data/protein.h5ad")

sc.pl.embedding(
    rna,
    basis="spatial",
    color="unsupervised_label",
    title="Protein leiden",
    s=0.8 
)

# %%
rna.var_names == protein.var_names
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
def accuracy_true_matching(transport):
    """
    Accuracy = fraction of RNA cells whose top transport match is the correct protein cell.
    """
    pred = transport.argmax(axis=1)
    true = np.arange(transport.shape[0])

    return (pred == true).mean()

# %%
# Store results
results = []

def compute_spatial_fgw_alignment(slice1, slice2, alpha, epsilon):
    """Compute FGW and FGW-SN alignment and return accuracy and JS divergence scores."""
   
    X = slice1.X.toarray()
    Y = slice2.X.toarray()
    
    # Compute spatial graphs
    coords1 = pd.DataFrame(slice1.obsm["spatial"], columns=["x", "y"])
    X_df = pd.DataFrame(X, columns=[f"PC{i+1}" for i in range(X.shape[1])])
    
    X_df["x"], X_df["y"], X_df["cell_type"] = coords1["x"].values, coords1["y"].values, slice1.obs["unsupervised_label"].values

    G1 = build_knn_graph_from2d(X_df, k=k)
    X_df["spatial_entropy"] = X_df.index.map(compute_spatial_entropy(G1))
    slice1_avg_expr = compute_average_neighbor_expression(G1, pd.DataFrame(X))
    
    coords2 = pd.DataFrame(slice2.obsm["spatial"], columns=["x", "y"])
    Y_df = pd.DataFrame(Y, columns=[f"PC{i+1}" for i in range(Y.shape[1])])
    Y_df["x"], Y_df["y"], Y_df["cell_type"] = coords2["x"].values, coords2["y"].values, slice2.obs["unsupervised_label"].values

    G2 = build_knn_graph_from2d(Y_df, k=k)
    Y_df["spatial_entropy"] = Y_df.index.map(compute_spatial_entropy(G2))
    slice2_avg_expr = compute_average_neighbor_expression(G2, pd.DataFrame(Y))
    
    # Compute cost matrices
    M = distance.cdist(X, Y).astype(float)
    C1 = distance.cdist(slice1.obsm["spatial"], slice1.obsm["spatial"]).astype(float)
    C2 = distance.cdist(slice2.obsm["spatial"], slice2.obsm["spatial"]).astype(float)
    C3 = np.abs(X_df["spatial_entropy"].values[:, np.newaxis] - Y_df["spatial_entropy"].values[np.newaxis, :])
    C4 = distance.cdist(slice1_avg_expr.values, slice2_avg_expr.values).astype(float)

    # Normalize matrices
    for mat in [M, C1, C2, C3, C4]:
        mat /= mat.max() if mat.max() > 0 else 1  # Avoid division by zero
    
    # Compute transport maps
    p, q = ot.unif(X.shape[0]), ot.unif(Y.shape[0])
    G0 = np.outer(p, q)

    FGW = compute_transport(G0, epsilon, alpha, C1, C2, p, q, M)
    FGW_SN = compute_transport(G0, epsilon, alpha, C1, C2, p, q, M, C3, C4)

    acc_fgw = accuracy_true_matching(FGW)
    acc_fgw_sn = accuracy_true_matching(FGW_SN)

    acc_fgw_cluster = compute_accuracy_max_prob(FGW, slice1.obs['unsupervised_label'], slice2.obs['unsupervised_label'])
    acc_fgw_sn_cluster = compute_accuracy_max_prob(FGW_SN, slice1.obs['unsupervised_label'], slice2.obs['unsupervised_label'])
    
    # Compute JS divergence
    js_fgw = compute_js_divergence_before_after(slice1, compute_transported_adata_argmax(slice1, slice2, FGW), k=20)
    js_fgw_sn = compute_js_divergence_before_after(slice1, compute_transported_adata_argmax(slice1, slice2, FGW_SN), k=20)

    return acc_fgw, acc_fgw_sn, acc_fgw_cluster, acc_fgw_sn_cluster, js_fgw, js_fgw_sn

# %%
alpha = 0.5  
epsilon = 0.1

# %%
def assign_grid(adata, grid_size=100):
    x = adata.obsm["spatial"][:, 0]
    y = adata.obsm["spatial"][:, 1]

    # Compute grid indices
    grid_x = (x // grid_size).astype(int)
    grid_y = (y // grid_size).astype(int)

    # Convert to Python strings BEFORE concatenating
    grid_x_str = grid_x.astype(str).astype(object)
    grid_y_str = grid_y.astype(str).astype(object)

    adata.obs["grid_id"] = grid_x_str + "_" + grid_y_str

    return adata

rna = assign_grid(rna, grid_size=100)
protein = assign_grid(protein, grid_size=100)

rna_bins = set(rna.obs["grid_id"])
prot_bins = set(protein.obs["grid_id"])

common_bins = list(rna_bins.intersection(prot_bins))
print("Common grids:", len(common_bins))
# Out:
# Common grids: 6340

# %%
results = []
transport_list_fgw = []
transport_list_fgw_sn = []


for i, g in enumerate(common_bins):
    print(f"Running alignment on grid {i}")

    rna_g = rna[rna.obs["grid_id"] == g].copy()
    prot_g = protein[protein.obs["grid_id"] == g].copy()

    # Skip tiny grids
    if rna_g.n_obs < 20 or prot_g.n_obs < 20:
        continue

    acc_fgw, acc_fgw_sn, acc_fgw_cluster, acc_fgw_sn_cluster, js_fgw, js_fgw_sn = \
        compute_spatial_fgw_alignment(rna_g, prot_g, alpha, epsilon)

    Pi, _, _ = align(rna_g, prot_g, alpha=0.2, gamma=50, epsilon=0.1, max_iter=100, balanced=False, use_gpu=False, normalize_xi=True, check_convergence=False)
    acc_dest = accuracy_true_matching(Pi)
    
    acc_dest_cluster = compute_accuracy_max_prob(Pi, rna_g.obs['unsupervised_label'], prot_g.obs['unsupervised_label'])
    js_dest = compute_js_divergence_before_after(rna_g, compute_transported_adata_argmax(rna_g, prot_g, Pi), k=20)
    
    # Save results
    results.append({
        "grid": g,
        "ACC_FGW": acc_fgw,
        "ACC_TOAST": acc_fgw_sn,
        "ACC_DEST": acc_dest,
        "ACC_FGW_CLUSTER": acc_fgw_cluster,
        "ACC_TOAST_CLUSTER": acc_fgw_sn_cluster,
        "ACC_DEST_CLUSTER": acc_dest_cluster,
        "JS_FGW": js_fgw,
        "JS_TOAST": js_fgw_sn,
        "JS_DEST": js_dest,
    })
# Out:
# Running alignment on grid 0
# Running alignment on grid 1
# Running alignment on grid 2
# Running alignment on grid 3
# Running alignment on grid 4
# Running alignment on grid 5
# Running alignment on grid 6
# Running alignment on grid 7
# Running alignment on grid 8
# Running alignment on grid 9
# Running alignment on grid 10
# Running alignment on grid 11
# Running alignment on grid 12
# Running alignment on grid 13
# Running alignment on grid 14
# Running alignment on grid 15
# Running alignment on grid 16
# Running alignment on grid 17
# Running alignment on grid 18
# Running alignment on grid 19
# Running alignment on grid 20
# Running alignment on grid 21
# Running alignment on grid 22
# Running alignment on grid 23
# Running alignment on grid 24
# Running alignment on grid 25
# Running alignment on grid 26
# Running alignment on grid 27
# Running alignment on grid 28
# Running alignment on grid 29
# Running alignment on grid 30
# Running alignment on grid 31
# Running alignment on grid 32
# Running alignment on grid 33
# Running alignment on grid 34
# Running alignment on grid 35
# Running alignment on grid 36
# Running alignment on grid 37
# Running alignment on grid 38
# Running alignment on grid 39
# Running alignment on grid 40
# Running alignment on grid 41
# Running alignment on grid 42
# Running alignment on grid 43
# Running alignment on grid 44
# Running alignment on grid 45
# Running alignment on grid 46
# Running alignment on grid 47
# Running alignment on grid 48
# Running alignment on grid 49
# Running alignment on grid 50
# Running alignment on grid 51
# Running alignment on grid 52
# Running alignment on grid 53
# Running alignment on grid 54
# Running alignment on grid 55
# Running alignment on grid 56
# Running alignment on grid 57
# Running alignment on grid 58
# Running alignment on grid 59
# Running alignment on grid 60
# Running alignment on grid 61
# Running alignment on grid 62
# Running alignment on grid 63
# Running alignment on grid 64
# Running alignment on grid 65
# Running alignment on grid 66
# Running alignment on grid 67
# Running alignment on grid 68
# Running alignment on grid 69
# Running alignment on grid 70
# Running alignment on grid 71
# Running alignment on grid 72
# Running alignment on grid 73
# Running alignment on grid 74
# Running alignment on grid 75
# Running alignment on grid 76
# Running alignment on grid 77
# Running alignment on grid 78
# Running alignment on grid 79
# Running alignment on grid 80
# Running alignment on grid 81
# Running alignment on grid 82
# Running alignment on grid 83
# Running alignment on grid 84
# Running alignment on grid 85
# Running alignment on grid 86
# Running alignment on grid 87
# Running alignment on grid 88
# Running alignment on grid 89
# Running alignment on grid 90
# Running alignment on grid 91
# Running alignment on grid 92
# Running alignment on grid 93
# Running alignment on grid 94
# Running alignment on grid 95
# Running alignment on grid 96
# Running alignment on grid 97
# Running alignment on grid 98
# Running alignment on grid 99
# Running alignment on grid 100
# Running alignment on grid 101
# Running alignment on grid 102
# Running alignment on grid 103
# Running alignment on grid 104
# Running alignment on grid 105
# Running alignment on grid 106
# Running alignment on grid 107
# Running alignment on grid 108
# Running alignment on grid 109
# Running alignment on grid 110
# Running alignment on grid 111
# Running alignment on grid 112
# Running alignment on grid 113
# Running alignment on grid 114
# Running alignment on grid 115
# Running alignment on grid 116
# Running alignment on grid 117
# Running alignment on grid 118
# Running alignment on grid 119
# Running alignment on grid 120
# Running alignment on grid 121
# Running alignment on grid 122
# Running alignment on grid 123
# Running alignment on grid 124
# Running alignment on grid 125
# Running alignment on grid 126
# Running alignment on grid 127
# Running alignment on grid 128
# Running alignment on grid 129
# Running alignment on grid 130
# Running alignment on grid 131
# Running alignment on grid 132
# Running alignment on grid 133
# Running alignment on grid 134
# Running alignment on grid 135
# Running alignment on grid 136
# Running alignment on grid 137
# Running alignment on grid 138
# Running alignment on grid 139
# Running alignment on grid 140
# Running alignment on grid 141
# Running alignment on grid 142
# Running alignment on grid 143
# Running alignment on grid 144
# Running alignment on grid 145
# Running alignment on grid 146
# Running alignment on grid 147
# Running alignment on grid 148
# Running alignment on grid 149
# Running alignment on grid 150
# Running alignment on grid 151
# Running alignment on grid 152
# Running alignment on grid 153
# Running alignment on grid 154
# Running alignment on grid 155
# Running alignment on grid 156
# Running alignment on grid 157
# Running alignment on grid 158
# Running alignment on grid 159
# Running alignment on grid 160
# Running alignment on grid 161
# Running alignment on grid 162
# Running alignment on grid 163
# Running alignment on grid 164
# Running alignment on grid 165
# Running alignment on grid 166
# Running alignment on grid 167
# Running alignment on grid 168
# Running alignment on grid 169
# Running alignment on grid 170
# Running alignment on grid 171
# Running alignment on grid 172
# Running alignment on grid 173
# Running alignment on grid 174
# Running alignment on grid 175
# Running alignment on grid 176
# Running alignment on grid 177
# Running alignment on grid 178
# Running alignment on grid 179
# Running alignment on grid 180
# Running alignment on grid 181
# Running alignment on grid 182
# Running alignment on grid 183
# Running alignment on grid 184
# Running alignment on grid 185
# Running alignment on grid 186
# Running alignment on grid 187
# Running alignment on grid 188
# Running alignment on grid 189
# Running alignment on grid 190
# Running alignment on grid 191
# Running alignment on grid 192
# Running alignment on grid 193
# Running alignment on grid 194
# Running alignment on grid 195
# Running alignment on grid 196
# Running alignment on grid 197
# Running alignment on grid 198
# Running alignment on grid 199
# Running alignment on grid 200
# Running alignment on grid 201
# Running alignment on grid 202
# Running alignment on grid 203
# Running alignment on grid 204
# Running alignment on grid 205
# Running alignment on grid 206
# Running alignment on grid 207
# Running alignment on grid 208
# Running alignment on grid 209
# Running alignment on grid 210
# Running alignment on grid 211
# Running alignment on grid 212
# Running alignment on grid 213
# Running alignment on grid 214
# Running alignment on grid 215
# Running alignment on grid 216
# Running alignment on grid 217
# Running alignment on grid 218
# Running alignment on grid 219
# Running alignment on grid 220
# Running alignment on grid 221
# Running alignment on grid 222
# Running alignment on grid 223
# Running alignment on grid 224
# Running alignment on grid 225
# Running alignment on grid 226
# Running alignment on grid 227
# Running alignment on grid 228
# Running alignment on grid 229
# Running alignment on grid 230
# Running alignment on grid 231
# Running alignment on grid 232
# Running alignment on grid 233
# Running alignment on grid 234
# Running alignment on grid 235
# Running alignment on grid 236
# Running alignment on grid 237
# Running alignment on grid 238
# Running alignment on grid 239
# Running alignment on grid 240
# Running alignment on grid 241
# Running alignment on grid 242
# Running alignment on grid 243
# Running alignment on grid 244
# Running alignment on grid 245
# Running alignment on grid 246
# Running alignment on grid 247
# Running alignment on grid 248
# Running alignment on grid 249
# Running alignment on grid 250
# Running alignment on grid 251
# Running alignment on grid 252
# Running alignment on grid 253
# Running alignment on grid 254
# Running alignment on grid 255
# Running alignment on grid 256
# Running alignment on grid 257
# Running alignment on grid 258
# Running alignment on grid 259
# Running alignment on grid 260
# Running alignment on grid 261
# Running alignment on grid 262
# Running alignment on grid 263
# Running alignment on grid 264
# Running alignment on grid 265
# Running alignment on grid 266
# Running alignment on grid 267
# Running alignment on grid 268
# Running alignment on grid 269
# Running alignment on grid 270
# Running alignment on grid 271
# Running alignment on grid 272
# Running alignment on grid 273
# Running alignment on grid 274
# Running alignment on grid 275
# Running alignment on grid 276
# Running alignment on grid 277
# Running alignment on grid 278
# Running alignment on grid 279
# Running alignment on grid 280
# Running alignment on grid 281
# Running alignment on grid 282
# Running alignment on grid 283
# Running alignment on grid 284
# Running alignment on grid 285
# Running alignment on grid 286
# Running alignment on grid 287
# Running alignment on grid 288
# Running alignment on grid 289
# Running alignment on grid 290
# Running alignment on grid 291
# Running alignment on grid 292
# Running alignment on grid 293
# Running alignment on grid 294
# Running alignment on grid 295
# Running alignment on grid 296
# Running alignment on grid 297
# Running alignment on grid 298
# Running alignment on grid 299
# Running alignment on grid 300
# Running alignment on grid 301
# Running alignment on grid 302
# Running alignment on grid 303
# Running alignment on grid 304
# Running alignment on grid 305
# Running alignment on grid 306
# Running alignment on grid 307
# Running alignment on grid 308
# Running alignment on grid 309
# Running alignment on grid 310
# Running alignment on grid 311
# Running alignment on grid 312
# Running alignment on grid 313
# Running alignment on grid 314
# Running alignment on grid 315
# Running alignment on grid 316
# Running alignment on grid 317
# Running alignment on grid 318
# Running alignment on grid 319
# Running alignment on grid 320
# Running alignment on grid 321
# Running alignment on grid 322
# Running alignment on grid 323
# Running alignment on grid 324
# Running alignment on grid 325
# Running alignment on grid 326
# Running alignment on grid 327
# Running alignment on grid 328
# Running alignment on grid 329
# Running alignment on grid 330
# Running alignment on grid 331
# Running alignment on grid 332
# Running alignment on grid 333
# Running alignment on grid 334
# Running alignment on grid 335
# Running alignment on grid 336
# Running alignment on grid 337
# Running alignment on grid 338
# Running alignment on grid 339
# Running alignment on grid 340
# Running alignment on grid 341
# Running alignment on grid 342
# Running alignment on grid 343
# Running alignment on grid 344
# Running alignment on grid 345
# Running alignment on grid 346
# Running alignment on grid 347
# Running alignment on grid 348
# Running alignment on grid 349
# Running alignment on grid 350
# Running alignment on grid 351
# Running alignment on grid 352
# Running alignment on grid 353
# Running alignment on grid 354
# Running alignment on grid 355
# Running alignment on grid 356
# Running alignment on grid 357
# Running alignment on grid 358
# Running alignment on grid 359
# Running alignment on grid 360
# Running alignment on grid 361
# Running alignment on grid 362
# Running alignment on grid 363
# Running alignment on grid 364
# Running alignment on grid 365
# Running alignment on grid 366
# Running alignment on grid 367
# Running alignment on grid 368
# Running alignment on grid 369
# Running alignment on grid 370
# Running alignment on grid 371
# Running alignment on grid 372
# Running alignment on grid 373
# Running alignment on grid 374
# Running alignment on grid 375
# Running alignment on grid 376
# Running alignment on grid 377
# Running alignment on grid 378
# Running alignment on grid 379
# Running alignment on grid 380
# Running alignment on grid 381
# Running alignment on grid 382
# Running alignment on grid 383
# Running alignment on grid 384
# Running alignment on grid 385
# Running alignment on grid 386
# Running alignment on grid 387
# Running alignment on grid 388
# Running alignment on grid 389
# Running alignment on grid 390
# Running alignment on grid 391
# Running alignment on grid 392
# Running alignment on grid 393
# Running alignment on grid 394
# Running alignment on grid 395
# Running alignment on grid 396
# Running alignment on grid 397
# Running alignment on grid 398
# Running alignment on grid 399
# Running alignment on grid 400
# Running alignment on grid 401
# Running alignment on grid 402
# Running alignment on grid 403
# Running alignment on grid 404
# Running alignment on grid 405
# Running alignment on grid 406
# Running alignment on grid 407
# Running alignment on grid 408
# Running alignment on grid 409
# Running alignment on grid 410
# Running alignment on grid 411
# Running alignment on grid 412
# Running alignment on grid 413
# Running alignment on grid 414
# Running alignment on grid 415
# Running alignment on grid 416
# Running alignment on grid 417
# Running alignment on grid 418
# Running alignment on grid 419
# Running alignment on grid 420
# Running alignment on grid 421
# Running alignment on grid 422
# Running alignment on grid 423
# Running alignment on grid 424
# Running alignment on grid 425
# Running alignment on grid 426
# Running alignment on grid 427
# Running alignment on grid 428
# Running alignment on grid 429
# Running alignment on grid 430
# Running alignment on grid 431
# Running alignment on grid 432
# Running alignment on grid 433
# Running alignment on grid 434
# Running alignment on grid 435
# Running alignment on grid 436
# Running alignment on grid 437
# Running alignment on grid 438
# Running alignment on grid 439
# Running alignment on grid 440
# Running alignment on grid 441
# Running alignment on grid 442
# Running alignment on grid 443
# Running alignment on grid 444
# Running alignment on grid 445
# Running alignment on grid 446
# Running alignment on grid 447
# Running alignment on grid 448
# Running alignment on grid 449
# Running alignment on grid 450
# Running alignment on grid 451
# Running alignment on grid 452
# Running alignment on grid 453
# Running alignment on grid 454
# Running alignment on grid 455
# Running alignment on grid 456
# Running alignment on grid 457
# Running alignment on grid 458
# Running alignment on grid 459
# Running alignment on grid 460
# Running alignment on grid 461
# Running alignment on grid 462
# Running alignment on grid 463
# Running alignment on grid 464
# Running alignment on grid 465
# Running alignment on grid 466
# Running alignment on grid 467
# Running alignment on grid 468
# Running alignment on grid 469
# Running alignment on grid 470
# Running alignment on grid 471
# Running alignment on grid 472
# Running alignment on grid 473
# Running alignment on grid 474
# Running alignment on grid 475
# Running alignment on grid 476
# Running alignment on grid 477
# Running alignment on grid 478
# Running alignment on grid 479
# Running alignment on grid 480
# Running alignment on grid 481
# Running alignment on grid 482
# Running alignment on grid 483
# Running alignment on grid 484
# Running alignment on grid 485
# Running alignment on grid 486
# Running alignment on grid 487
# Running alignment on grid 488
# Running alignment on grid 489
# Running alignment on grid 490
# Running alignment on grid 491
# Running alignment on grid 492
# Running alignment on grid 493
# Running alignment on grid 494
# Running alignment on grid 495
# Running alignment on grid 496
# Running alignment on grid 497
# Running alignment on grid 498
# Running alignment on grid 499
# Running alignment on grid 500
# Running alignment on grid 501
# Running alignment on grid 502
# Running alignment on grid 503
# Running alignment on grid 504
# Running alignment on grid 505
# Running alignment on grid 506
# Running alignment on grid 507
# Running alignment on grid 508
# Running alignment on grid 509
# Running alignment on grid 510
# Running alignment on grid 511
# Running alignment on grid 512
# Running alignment on grid 513
# Running alignment on grid 514
# Running alignment on grid 515
# Running alignment on grid 516
# Running alignment on grid 517
# Running alignment on grid 518
# Running alignment on grid 519
# Running alignment on grid 520
# Running alignment on grid 521
# Running alignment on grid 522
# Running alignment on grid 523
# Running alignment on grid 524
# Running alignment on grid 525
# Running alignment on grid 526
# Running alignment on grid 527
# Running alignment on grid 528
# Running alignment on grid 529
# Running alignment on grid 530
# Running alignment on grid 531
# Running alignment on grid 532
# Running alignment on grid 533
# Running alignment on grid 534
# Running alignment on grid 535
# Running alignment on grid 536
# Running alignment on grid 537
# Running alignment on grid 538
# Running alignment on grid 539
# Running alignment on grid 540
# Running alignment on grid 541
# Running alignment on grid 542
# Running alignment on grid 543
# Running alignment on grid 544
# Running alignment on grid 545
# Running alignment on grid 546
# Running alignment on grid 547
# Running alignment on grid 548
# Running alignment on grid 549
# Running alignment on grid 550
# Running alignment on grid 551
# Running alignment on grid 552
# Running alignment on grid 553
# Running alignment on grid 554
# Running alignment on grid 555
# Running alignment on grid 556
# Running alignment on grid 557
# Running alignment on grid 558
# Running alignment on grid 559
# Running alignment on grid 560
# Running alignment on grid 561
# Running alignment on grid 562
# Running alignment on grid 563
# Running alignment on grid 564
# Running alignment on grid 565
# Running alignment on grid 566
# Running alignment on grid 567
# Running alignment on grid 568
# Running alignment on grid 569
# Running alignment on grid 570
# Running alignment on grid 571
# Running alignment on grid 572
# Running alignment on grid 573
# Running alignment on grid 574
# Running alignment on grid 575
# Running alignment on grid 576
# Running alignment on grid 577
# Running alignment on grid 578
# Running alignment on grid 579
# Running alignment on grid 580
# Running alignment on grid 581
# Running alignment on grid 582
# Running alignment on grid 583
# Running alignment on grid 584
# Running alignment on grid 585
# Running alignment on grid 586
# Running alignment on grid 587
# Running alignment on grid 588
# Running alignment on grid 589
# Running alignment on grid 590
# Running alignment on grid 591
# Running alignment on grid 592
# Running alignment on grid 593
# Running alignment on grid 594
# Running alignment on grid 595
# Running alignment on grid 596
# Running alignment on grid 597
# Running alignment on grid 598
# Running alignment on grid 599
# Running alignment on grid 600
# Running alignment on grid 601
# Running alignment on grid 602
# Running alignment on grid 603
# Running alignment on grid 604
# Running alignment on grid 605
# Running alignment on grid 606
# Running alignment on grid 607
# Running alignment on grid 608
# Running alignment on grid 609
# Running alignment on grid 610
# Running alignment on grid 611
# Running alignment on grid 612
# Running alignment on grid 613
# Running alignment on grid 614
# Running alignment on grid 615
# Running alignment on grid 616
# Running alignment on grid 617
# Running alignment on grid 618
# Running alignment on grid 619
# Running alignment on grid 620
# Running alignment on grid 621
# Running alignment on grid 622
# Running alignment on grid 623
# Running alignment on grid 624
# Running alignment on grid 625
# Running alignment on grid 626
# Running alignment on grid 627
# Running alignment on grid 628
# Running alignment on grid 629
# Running alignment on grid 630
# Running alignment on grid 631
# Running alignment on grid 632
# Running alignment on grid 633
# Running alignment on grid 634
# Running alignment on grid 635
# Running alignment on grid 636
# Running alignment on grid 637
# Running alignment on grid 638
# Running alignment on grid 639
# Running alignment on grid 640
# Running alignment on grid 641
# Running alignment on grid 642
# Running alignment on grid 643
# Running alignment on grid 644
# Running alignment on grid 645
# Running alignment on grid 646
# Running alignment on grid 647
# Running alignment on grid 648
# Running alignment on grid 649
# Running alignment on grid 650
# Running alignment on grid 651
# Running alignment on grid 652
# Running alignment on grid 653
# Running alignment on grid 654
# Running alignment on grid 655
# Running alignment on grid 656
# Running alignment on grid 657
# Running alignment on grid 658
# Running alignment on grid 659
# Running alignment on grid 660
# Running alignment on grid 661
# Running alignment on grid 662
# Running alignment on grid 663
# Running alignment on grid 664
# Running alignment on grid 665
# Running alignment on grid 666
# Running alignment on grid 667
# Running alignment on grid 668
# Running alignment on grid 669
# Running alignment on grid 670
# Running alignment on grid 671
# Running alignment on grid 672
# Running alignment on grid 673
# Running alignment on grid 674
# Running alignment on grid 675
# Running alignment on grid 676
# Running alignment on grid 677
# Running alignment on grid 678
# Running alignment on grid 679
# Running alignment on grid 680
# Running alignment on grid 681
# Running alignment on grid 682
# Running alignment on grid 683
# Running alignment on grid 684
# Running alignment on grid 685
# Running alignment on grid 686
# Running alignment on grid 687
# Running alignment on grid 688
# Running alignment on grid 689
# Running alignment on grid 690
# Running alignment on grid 691
# Running alignment on grid 692
# Running alignment on grid 693
# Running alignment on grid 694
# Running alignment on grid 695
# Running alignment on grid 696
# Running alignment on grid 697
# Running alignment on grid 698
# Running alignment on grid 699
# Running alignment on grid 700
# Running alignment on grid 701
# Running alignment on grid 702
# Running alignment on grid 703
# Running alignment on grid 704
# Running alignment on grid 705
# Running alignment on grid 706
# Running alignment on grid 707
# Running alignment on grid 708
# Running alignment on grid 709
# Running alignment on grid 710
# Running alignment on grid 711
# Running alignment on grid 712
# Running alignment on grid 713
# Running alignment on grid 714
# Running alignment on grid 715
# Running alignment on grid 716
# Running alignment on grid 717
# Running alignment on grid 718
# Running alignment on grid 719
# Running alignment on grid 720
# Running alignment on grid 721
# Running alignment on grid 722
# Running alignment on grid 723
# Running alignment on grid 724
# Running alignment on grid 725
# Running alignment on grid 726
# Running alignment on grid 727
# Running alignment on grid 728
# Running alignment on grid 729
# Running alignment on grid 730
# Running alignment on grid 731
# Running alignment on grid 732
# Running alignment on grid 733
# Running alignment on grid 734
# Running alignment on grid 735
# Running alignment on grid 736
# Running alignment on grid 737
# Running alignment on grid 738
# Running alignment on grid 739
# Running alignment on grid 740
# Running alignment on grid 741
# Running alignment on grid 742
# Running alignment on grid 743
# Running alignment on grid 744
# Running alignment on grid 745
# Running alignment on grid 746
# Running alignment on grid 747
# Running alignment on grid 748
# Running alignment on grid 749
# Running alignment on grid 750
# Running alignment on grid 751
# Running alignment on grid 752
# Running alignment on grid 753
# Running alignment on grid 754
# Running alignment on grid 755
# Running alignment on grid 756
# Running alignment on grid 757
# Running alignment on grid 758
# Running alignment on grid 759
# Running alignment on grid 760
# Running alignment on grid 761
# Running alignment on grid 762
# Running alignment on grid 763
# Running alignment on grid 764
# Running alignment on grid 765
# Running alignment on grid 766
# Running alignment on grid 767
# Running alignment on grid 768
# Running alignment on grid 769
# Running alignment on grid 770
# Running alignment on grid 771
# Running alignment on grid 772
# Running alignment on grid 773
# Running alignment on grid 774
# Running alignment on grid 775
# Running alignment on grid 776
# Running alignment on grid 777
# Running alignment on grid 778
# Running alignment on grid 779
# Running alignment on grid 780
# Running alignment on grid 781
# Running alignment on grid 782
# Running alignment on grid 783
# Running alignment on grid 784
# Running alignment on grid 785
# Running alignment on grid 786
# Running alignment on grid 787
# Running alignment on grid 788
# Running alignment on grid 789
# Running alignment on grid 790
# Running alignment on grid 791
# Running alignment on grid 792
# Running alignment on grid 793
# Running alignment on grid 794
# Running alignment on grid 795
# Running alignment on grid 796
# Running alignment on grid 797
# Running alignment on grid 798
# Running alignment on grid 799
# Running alignment on grid 800
# Running alignment on grid 801
# Running alignment on grid 802
# Running alignment on grid 803
# Running alignment on grid 804
# Running alignment on grid 805
# Running alignment on grid 806
# Running alignment on grid 807
# Running alignment on grid 808
# Running alignment on grid 809
# Running alignment on grid 810
# Running alignment on grid 811
# Running alignment on grid 812
# Running alignment on grid 813
# Running alignment on grid 814
# Running alignment on grid 815
# Running alignment on grid 816
# Running alignment on grid 817
# Running alignment on grid 818
# Running alignment on grid 819
# Running alignment on grid 820
# Running alignment on grid 821
# Running alignment on grid 822
# Running alignment on grid 823
# Running alignment on grid 824
# Running alignment on grid 825
# Running alignment on grid 826
# Running alignment on grid 827
# Running alignment on grid 828
# Running alignment on grid 829
# Running alignment on grid 830
# Running alignment on grid 831
# Running alignment on grid 832
# Running alignment on grid 833
# Running alignment on grid 834
# Running alignment on grid 835
# Running alignment on grid 836
# Running alignment on grid 837
# Running alignment on grid 838
# Running alignment on grid 839
# Running alignment on grid 840
# Running alignment on grid 841
# Running alignment on grid 842
# Running alignment on grid 843
# Running alignment on grid 844
# Running alignment on grid 845
# Running alignment on grid 846
# Running alignment on grid 847
# Running alignment on grid 848
# Running alignment on grid 849
# Running alignment on grid 850
# Running alignment on grid 851
# Running alignment on grid 852
# Running alignment on grid 853
# Running alignment on grid 854
# Running alignment on grid 855
# Running alignment on grid 856
# Running alignment on grid 857
# Running alignment on grid 858
# Running alignment on grid 859
# Running alignment on grid 860
# Running alignment on grid 861
# Running alignment on grid 862
# Running alignment on grid 863
# Running alignment on grid 864
# Running alignment on grid 865
# Running alignment on grid 866
# Running alignment on grid 867
# Running alignment on grid 868
# Running alignment on grid 869
# Running alignment on grid 870
# Running alignment on grid 871
# Running alignment on grid 872
# Running alignment on grid 873
# Running alignment on grid 874
# Running alignment on grid 875
# Running alignment on grid 876
# Running alignment on grid 877
# Running alignment on grid 878
# Running alignment on grid 879
# Running alignment on grid 880
# Running alignment on grid 881
# Running alignment on grid 882
# Running alignment on grid 883
# Running alignment on grid 884
# Running alignment on grid 885
# Running alignment on grid 886
# Running alignment on grid 887
# Running alignment on grid 888
# Running alignment on grid 889
# Running alignment on grid 890
# Running alignment on grid 891
# Running alignment on grid 892
# Running alignment on grid 893
# Running alignment on grid 894
# Running alignment on grid 895
# Running alignment on grid 896
# Running alignment on grid 897
# Running alignment on grid 898
# Running alignment on grid 899
# Running alignment on grid 900
# Running alignment on grid 901
# Running alignment on grid 902
# Running alignment on grid 903
# Running alignment on grid 904
# Running alignment on grid 905
# Running alignment on grid 906
# Running alignment on grid 907
# Running alignment on grid 908
# Running alignment on grid 909
# Running alignment on grid 910
# Running alignment on grid 911
# Running alignment on grid 912
# Running alignment on grid 913
# Running alignment on grid 914
# Running alignment on grid 915
# Running alignment on grid 916
# Running alignment on grid 917
# Running alignment on grid 918
# Running alignment on grid 919
# Running alignment on grid 920
# Running alignment on grid 921
# Running alignment on grid 922
# Running alignment on grid 923
# Running alignment on grid 924
# Running alignment on grid 925
# Running alignment on grid 926
# Running alignment on grid 927
# Running alignment on grid 928
# Running alignment on grid 929
# Running alignment on grid 930
# Running alignment on grid 931
# Running alignment on grid 932
# Running alignment on grid 933
# Running alignment on grid 934
# Running alignment on grid 935
# Running alignment on grid 936
# Running alignment on grid 937
# Running alignment on grid 938
# Running alignment on grid 939
# Running alignment on grid 940
# Running alignment on grid 941
# Running alignment on grid 942
# Running alignment on grid 943
# Running alignment on grid 944
# Running alignment on grid 945
# Running alignment on grid 946
# Running alignment on grid 947
# Running alignment on grid 948
# Running alignment on grid 949
# Running alignment on grid 950
# Running alignment on grid 951
# Running alignment on grid 952
# Running alignment on grid 953
# Running alignment on grid 954
# Running alignment on grid 955
# Running alignment on grid 956
# Running alignment on grid 957
# Running alignment on grid 958
# Running alignment on grid 959
# Running alignment on grid 960
# Running alignment on grid 961
# Running alignment on grid 962
# Running alignment on grid 963
# Running alignment on grid 964
# Running alignment on grid 965
# Running alignment on grid 966
# Running alignment on grid 967
# Running alignment on grid 968
# Running alignment on grid 969
# Running alignment on grid 970
# Running alignment on grid 971
# Running alignment on grid 972
# Running alignment on grid 973
# Running alignment on grid 974
# Running alignment on grid 975
# Running alignment on grid 976
# Running alignment on grid 977
# Running alignment on grid 978
# Running alignment on grid 979
# Running alignment on grid 980
# Running alignment on grid 981
# Running alignment on grid 982
# Running alignment on grid 983
# Running alignment on grid 984
# Running alignment on grid 985
# Running alignment on grid 986
# Running alignment on grid 987
# Running alignment on grid 988
# Running alignment on grid 989
# Running alignment on grid 990
# Running alignment on grid 991
# Running alignment on grid 992
# Running alignment on grid 993
# Running alignment on grid 994
# Running alignment on grid 995
# Running alignment on grid 996
# Running alignment on grid 997
# Running alignment on grid 998
# Running alignment on grid 999
# Running alignment on grid 1000
# Running alignment on grid 1001
# Running alignment on grid 1002
# Running alignment on grid 1003
# Running alignment on grid 1004
# Running alignment on grid 1005
# Running alignment on grid 1006
# Running alignment on grid 1007
# Running alignment on grid 1008
# Running alignment on grid 1009
# Running alignment on grid 1010
# Running alignment on grid 1011
# Running alignment on grid 1012
# Running alignment on grid 1013
# Running alignment on grid 1014
# Running alignment on grid 1015
# Running alignment on grid 1016
# Running alignment on grid 1017
# Running alignment on grid 1018
# Running alignment on grid 1019
# Running alignment on grid 1020
# Running alignment on grid 1021
# Running alignment on grid 1022
# Running alignment on grid 1023
# Running alignment on grid 1024
# Running alignment on grid 1025
# Running alignment on grid 1026
# Running alignment on grid 1027
# Running alignment on grid 1028
# Running alignment on grid 1029
# Running alignment on grid 1030
# Running alignment on grid 1031
# Running alignment on grid 1032
# Running alignment on grid 1033
# Running alignment on grid 1034
# Running alignment on grid 1035
# Running alignment on grid 1036
# Running alignment on grid 1037
# Running alignment on grid 1038
# Running alignment on grid 1039
# Running alignment on grid 1040
# Running alignment on grid 1041
# Running alignment on grid 1042
# Running alignment on grid 1043
# Running alignment on grid 1044
# Running alignment on grid 1045
# Running alignment on grid 1046
# Running alignment on grid 1047
# Running alignment on grid 1048
# Running alignment on grid 1049
# Running alignment on grid 1050
# Running alignment on grid 1051
# Running alignment on grid 1052
# Running alignment on grid 1053
# Running alignment on grid 1054
# Running alignment on grid 1055
# Running alignment on grid 1056
# Running alignment on grid 1057
# Running alignment on grid 1058
# Running alignment on grid 1059
# Running alignment on grid 1060
# Running alignment on grid 1061
# Running alignment on grid 1062
# Running alignment on grid 1063
# Running alignment on grid 1064
# Running alignment on grid 1065
# Running alignment on grid 1066
# Running alignment on grid 1067
# Running alignment on grid 1068
# Running alignment on grid 1069
# Running alignment on grid 1070
# Running alignment on grid 1071
# Running alignment on grid 1072
# Running alignment on grid 1073
# Running alignment on grid 1074
# Running alignment on grid 1075
# Running alignment on grid 1076
# Running alignment on grid 1077
# Running alignment on grid 1078
# Running alignment on grid 1079
# Running alignment on grid 1080
# Running alignment on grid 1081
# Running alignment on grid 1082
# Running alignment on grid 1083
# Running alignment on grid 1084
# Running alignment on grid 1085
# Running alignment on grid 1086
# Running alignment on grid 1087
# Running alignment on grid 1088
# Running alignment on grid 1089
# Running alignment on grid 1090
# Running alignment on grid 1091
# Running alignment on grid 1092
# Running alignment on grid 1093
# Running alignment on grid 1094
# Running alignment on grid 1095
# Running alignment on grid 1096
# Running alignment on grid 1097
# Running alignment on grid 1098
# Running alignment on grid 1099
# Running alignment on grid 1100
# Running alignment on grid 1101
# Running alignment on grid 1102
# Running alignment on grid 1103
# Running alignment on grid 1104
# Running alignment on grid 1105
# Running alignment on grid 1106
# Running alignment on grid 1107
# Running alignment on grid 1108
# Running alignment on grid 1109
# Running alignment on grid 1110
# Running alignment on grid 1111
# Running alignment on grid 1112
# Running alignment on grid 1113
# Running alignment on grid 1114
# Running alignment on grid 1115
# Running alignment on grid 1116
# Running alignment on grid 1117
# Running alignment on grid 1118
# Running alignment on grid 1119
# Running alignment on grid 1120
# Running alignment on grid 1121
# Running alignment on grid 1122
# Running alignment on grid 1123
# Running alignment on grid 1124
# Running alignment on grid 1125
# Running alignment on grid 1126
# Running alignment on grid 1127
# Running alignment on grid 1128
# Running alignment on grid 1129
# Running alignment on grid 1130
# Running alignment on grid 1131
# Running alignment on grid 1132
# Running alignment on grid 1133
# Running alignment on grid 1134
# Running alignment on grid 1135
# Running alignment on grid 1136
# Running alignment on grid 1137
# Running alignment on grid 1138
# Running alignment on grid 1139
# Running alignment on grid 1140
# Running alignment on grid 1141
# Running alignment on grid 1142
# Running alignment on grid 1143
# Running alignment on grid 1144
# Running alignment on grid 1145
# Running alignment on grid 1146
# Running alignment on grid 1147
# Running alignment on grid 1148
# Running alignment on grid 1149
# Running alignment on grid 1150
# Running alignment on grid 1151
# Running alignment on grid 1152
# Running alignment on grid 1153
# Running alignment on grid 1154
# Running alignment on grid 1155
# Running alignment on grid 1156
# Running alignment on grid 1157
# Running alignment on grid 1158
# Running alignment on grid 1159
# Running alignment on grid 1160
# Running alignment on grid 1161
# Running alignment on grid 1162
# Running alignment on grid 1163
# Running alignment on grid 1164
# Running alignment on grid 1165
# Running alignment on grid 1166
# Running alignment on grid 1167
# Running alignment on grid 1168
# Running alignment on grid 1169
# Running alignment on grid 1170
# Running alignment on grid 1171
# Running alignment on grid 1172
# Running alignment on grid 1173
# Running alignment on grid 1174
# Running alignment on grid 1175
# Running alignment on grid 1176
# Running alignment on grid 1177
# Running alignment on grid 1178
# Running alignment on grid 1179
# Running alignment on grid 1180
# Running alignment on grid 1181
# Running alignment on grid 1182
# Running alignment on grid 1183
# Running alignment on grid 1184
# Running alignment on grid 1185
# Running alignment on grid 1186
# Running alignment on grid 1187
# Running alignment on grid 1188
# Running alignment on grid 1189
# Running alignment on grid 1190
# Running alignment on grid 1191
# Running alignment on grid 1192
# Running alignment on grid 1193
# Running alignment on grid 1194
# Running alignment on grid 1195
# Running alignment on grid 1196
# Running alignment on grid 1197
# Running alignment on grid 1198
# Running alignment on grid 1199
# Running alignment on grid 1200
# Running alignment on grid 1201
# Running alignment on grid 1202
# Running alignment on grid 1203
# Running alignment on grid 1204
# Running alignment on grid 1205
# Running alignment on grid 1206
# Running alignment on grid 1207
# Running alignment on grid 1208
# Running alignment on grid 1209
# Running alignment on grid 1210
# Running alignment on grid 1211
# Running alignment on grid 1212
# Running alignment on grid 1213
# Running alignment on grid 1214
# Running alignment on grid 1215
# Running alignment on grid 1216
# Running alignment on grid 1217
# Running alignment on grid 1218
# Running alignment on grid 1219
# Running alignment on grid 1220
# Running alignment on grid 1221
# Running alignment on grid 1222
# Running alignment on grid 1223
# Running alignment on grid 1224
# Running alignment on grid 1225
# Running alignment on grid 1226
# Running alignment on grid 1227
# Running alignment on grid 1228
# Running alignment on grid 1229
# Running alignment on grid 1230
# Running alignment on grid 1231
# Running alignment on grid 1232
# Running alignment on grid 1233
# Running alignment on grid 1234
# Running alignment on grid 1235
# Running alignment on grid 1236
# Running alignment on grid 1237
# Running alignment on grid 1238
# Running alignment on grid 1239
# Running alignment on grid 1240
# Running alignment on grid 1241
# Running alignment on grid 1242
# Running alignment on grid 1243
# Running alignment on grid 1244
# Running alignment on grid 1245
# Running alignment on grid 1246
# Running alignment on grid 1247
# Running alignment on grid 1248
# Running alignment on grid 1249
# Running alignment on grid 1250
# Running alignment on grid 1251
# Running alignment on grid 1252
# Running alignment on grid 1253
# Running alignment on grid 1254
# Running alignment on grid 1255
# Running alignment on grid 1256
# Running alignment on grid 1257
# Running alignment on grid 1258
# Running alignment on grid 1259
# Running alignment on grid 1260
# Running alignment on grid 1261
# Running alignment on grid 1262
# Running alignment on grid 1263
# Running alignment on grid 1264
# Running alignment on grid 1265
# Running alignment on grid 1266
# Running alignment on grid 1267
# Running alignment on grid 1268
# Running alignment on grid 1269
# Running alignment on grid 1270
# Running alignment on grid 1271
# Running alignment on grid 1272
# Running alignment on grid 1273
# Running alignment on grid 1274
# Running alignment on grid 1275
# Running alignment on grid 1276
# Running alignment on grid 1277
# Running alignment on grid 1278
# Running alignment on grid 1279
# Running alignment on grid 1280
# Running alignment on grid 1281
# Running alignment on grid 1282
# Running alignment on grid 1283
# Running alignment on grid 1284
# Running alignment on grid 1285
# Running alignment on grid 1286
# Running alignment on grid 1287
# Running alignment on grid 1288
# Running alignment on grid 1289
# Running alignment on grid 1290
# Running alignment on grid 1291
# Running alignment on grid 1292
# Running alignment on grid 1293
# Running alignment on grid 1294
# Running alignment on grid 1295
# Running alignment on grid 1296
# Running alignment on grid 1297
# Running alignment on grid 1298
# Running alignment on grid 1299
# Running alignment on grid 1300
# Running alignment on grid 1301
# Running alignment on grid 1302
# Running alignment on grid 1303
# Running alignment on grid 1304
# Running alignment on grid 1305
# Running alignment on grid 1306
# Running alignment on grid 1307
# Running alignment on grid 1308
# Running alignment on grid 1309
# Running alignment on grid 1310
# Running alignment on grid 1311
# Running alignment on grid 1312
# Running alignment on grid 1313
# Running alignment on grid 1314
# Running alignment on grid 1315
# Running alignment on grid 1316
# Running alignment on grid 1317
# Running alignment on grid 1318
# Running alignment on grid 1319
# Running alignment on grid 1320
# Running alignment on grid 1321
# Running alignment on grid 1322
# Running alignment on grid 1323
# Running alignment on grid 1324
# Running alignment on grid 1325
# Running alignment on grid 1326
# Running alignment on grid 1327
# Running alignment on grid 1328
# Running alignment on grid 1329
# Running alignment on grid 1330
# Running alignment on grid 1331
# Running alignment on grid 1332
# Running alignment on grid 1333
# Running alignment on grid 1334
# Running alignment on grid 1335
# Running alignment on grid 1336
# Running alignment on grid 1337
# Running alignment on grid 1338
# Running alignment on grid 1339
# Running alignment on grid 1340
# Running alignment on grid 1341
# Running alignment on grid 1342
# Running alignment on grid 1343
# Running alignment on grid 1344
# Running alignment on grid 1345
# Running alignment on grid 1346
# Running alignment on grid 1347
# Running alignment on grid 1348
# Running alignment on grid 1349
# Running alignment on grid 1350
# Running alignment on grid 1351
# Running alignment on grid 1352
# Running alignment on grid 1353
# Running alignment on grid 1354
# Running alignment on grid 1355
# Running alignment on grid 1356
# Running alignment on grid 1357
# Running alignment on grid 1358
# Running alignment on grid 1359
# Running alignment on grid 1360
# Running alignment on grid 1361
# Running alignment on grid 1362
# Running alignment on grid 1363
# Running alignment on grid 1364
# Running alignment on grid 1365
# Running alignment on grid 1366
# Running alignment on grid 1367
# Running alignment on grid 1368
# Running alignment on grid 1369
# Running alignment on grid 1370
# Running alignment on grid 1371
# Running alignment on grid 1372
# Running alignment on grid 1373
# Running alignment on grid 1374
# Running alignment on grid 1375
# Running alignment on grid 1376
# Running alignment on grid 1377
# Running alignment on grid 1378
# Running alignment on grid 1379
# Running alignment on grid 1380
# Running alignment on grid 1381
# Running alignment on grid 1382
# Running alignment on grid 1383
# Running alignment on grid 1384
# Running alignment on grid 1385
# Running alignment on grid 1386
# Running alignment on grid 1387
# Running alignment on grid 1388
# Running alignment on grid 1389
# Running alignment on grid 1390
# Running alignment on grid 1391
# Running alignment on grid 1392
# Running alignment on grid 1393
# Running alignment on grid 1394
# Running alignment on grid 1395
# Running alignment on grid 1396
# Running alignment on grid 1397
# Running alignment on grid 1398
# Running alignment on grid 1399
# Running alignment on grid 1400
# Running alignment on grid 1401
# Running alignment on grid 1402
# Running alignment on grid 1403
# Running alignment on grid 1404
# Running alignment on grid 1405
# Running alignment on grid 1406
# Running alignment on grid 1407
# Running alignment on grid 1408
# Running alignment on grid 1409
# Running alignment on grid 1410
# Running alignment on grid 1411
# Running alignment on grid 1412
# Running alignment on grid 1413
# Running alignment on grid 1414
# Running alignment on grid 1415
# Running alignment on grid 1416
# Running alignment on grid 1417
# Running alignment on grid 1418
# Running alignment on grid 1419
# Running alignment on grid 1420
# Running alignment on grid 1421
# Running alignment on grid 1422
# Running alignment on grid 1423
# Running alignment on grid 1424
# Running alignment on grid 1425
# Running alignment on grid 1426
# Running alignment on grid 1427
# Running alignment on grid 1428
# Running alignment on grid 1429
# Running alignment on grid 1430
# Running alignment on grid 1431
# Running alignment on grid 1432
# Running alignment on grid 1433
# Running alignment on grid 1434
# Running alignment on grid 1435
# Running alignment on grid 1436
# Running alignment on grid 1437
# Running alignment on grid 1438
# Running alignment on grid 1439
# Running alignment on grid 1440
# Running alignment on grid 1441
# Running alignment on grid 1442
# Running alignment on grid 1443
# Running alignment on grid 1444
# Running alignment on grid 1445
# Running alignment on grid 1446
# Running alignment on grid 1447
# Running alignment on grid 1448
# Running alignment on grid 1449
# Running alignment on grid 1450
# Running alignment on grid 1451
# Running alignment on grid 1452
# Running alignment on grid 1453
# Running alignment on grid 1454
# Running alignment on grid 1455
# Running alignment on grid 1456
# Running alignment on grid 1457
# Running alignment on grid 1458
# Running alignment on grid 1459
# Running alignment on grid 1460
# Running alignment on grid 1461
# Running alignment on grid 1462
# Running alignment on grid 1463
# Running alignment on grid 1464
# Running alignment on grid 1465
# Running alignment on grid 1466
# Running alignment on grid 1467
# Running alignment on grid 1468
# Running alignment on grid 1469
# Running alignment on grid 1470
# Running alignment on grid 1471
# Running alignment on grid 1472
# Running alignment on grid 1473
# Running alignment on grid 1474
# Running alignment on grid 1475
# Running alignment on grid 1476
# Running alignment on grid 1477
# Running alignment on grid 1478
# Running alignment on grid 1479
# Running alignment on grid 1480
# Running alignment on grid 1481
# Running alignment on grid 1482
# Running alignment on grid 1483
# Running alignment on grid 1484
# Running alignment on grid 1485
# Running alignment on grid 1486
# Running alignment on grid 1487
# Running alignment on grid 1488
# Running alignment on grid 1489
# Running alignment on grid 1490
# Running alignment on grid 1491
# Running alignment on grid 1492
# Running alignment on grid 1493
# Running alignment on grid 1494
# Running alignment on grid 1495
# Running alignment on grid 1496
# Running alignment on grid 1497
# Running alignment on grid 1498
# Running alignment on grid 1499
# Running alignment on grid 1500
# Running alignment on grid 1501
# Running alignment on grid 1502
# Running alignment on grid 1503
# Running alignment on grid 1504
# Running alignment on grid 1505
# Running alignment on grid 1506
# Running alignment on grid 1507
# Running alignment on grid 1508
# Running alignment on grid 1509
# Running alignment on grid 1510
# Running alignment on grid 1511
# Running alignment on grid 1512
# Running alignment on grid 1513
# Running alignment on grid 1514
# Running alignment on grid 1515
# Running alignment on grid 1516
# Running alignment on grid 1517
# Running alignment on grid 1518
# Running alignment on grid 1519
# Running alignment on grid 1520
# Running alignment on grid 1521
# Running alignment on grid 1522
# Running alignment on grid 1523
# Running alignment on grid 1524
# Running alignment on grid 1525
# Running alignment on grid 1526
# Running alignment on grid 1527
# Running alignment on grid 1528
# Running alignment on grid 1529
# Running alignment on grid 1530
# Running alignment on grid 1531
# Running alignment on grid 1532
# Running alignment on grid 1533
# Running alignment on grid 1534
# Running alignment on grid 1535
# Running alignment on grid 1536
# Running alignment on grid 1537
# Running alignment on grid 1538
# Running alignment on grid 1539
# Running alignment on grid 1540
# Running alignment on grid 1541
# Running alignment on grid 1542
# Running alignment on grid 1543
# Running alignment on grid 1544
# Running alignment on grid 1545
# Running alignment on grid 1546
# Running alignment on grid 1547
# Running alignment on grid 1548
# Running alignment on grid 1549
# Running alignment on grid 1550
# Running alignment on grid 1551
# Running alignment on grid 1552
# Running alignment on grid 1553
# Running alignment on grid 1554
# Running alignment on grid 1555
# Running alignment on grid 1556
# Running alignment on grid 1557
# Running alignment on grid 1558
# Running alignment on grid 1559
# Running alignment on grid 1560
# Running alignment on grid 1561
# Running alignment on grid 1562
# Running alignment on grid 1563
# Running alignment on grid 1564
# Running alignment on grid 1565
# Running alignment on grid 1566
# Running alignment on grid 1567
# Running alignment on grid 1568
# Running alignment on grid 1569
# Running alignment on grid 1570
# Running alignment on grid 1571
# Running alignment on grid 1572
# Running alignment on grid 1573
# Running alignment on grid 1574
# Running alignment on grid 1575
# Running alignment on grid 1576
# Running alignment on grid 1577
# Running alignment on grid 1578
# Running alignment on grid 1579
# Running alignment on grid 1580
# Running alignment on grid 1581
# Running alignment on grid 1582
# Running alignment on grid 1583
# ...
# Running alignment on grid 5824
# Running alignment on grid 5825
# Running alignment on grid 5826
# Running alignment on grid 5827
# Running alignment on grid 5828
# Running alignment on grid 5829
# Running alignment on grid 5830
# Running alignment on grid 5831
# Running alignment on grid 5832
# Running alignment on grid 5833
# Running alignment on grid 5834
# Running alignment on grid 5835
# Running alignment on grid 5836
# Running alignment on grid 5837
# Running alignment on grid 5838
# Running alignment on grid 5839
# Running alignment on grid 5840
# Running alignment on grid 5841
# Running alignment on grid 5842
# Running alignment on grid 5843
# Running alignment on grid 5844
# Running alignment on grid 5845
# Running alignment on grid 5846
# Running alignment on grid 5847
# Running alignment on grid 5848
# Running alignment on grid 5849
# Running alignment on grid 5850
# Running alignment on grid 5851
# Running alignment on grid 5852
# Running alignment on grid 5853
# Running alignment on grid 5854
# Running alignment on grid 5855
# Running alignment on grid 5856
# Running alignment on grid 5857
# Running alignment on grid 5858
# Running alignment on grid 5859
# Running alignment on grid 5860
# Running alignment on grid 5861
# Running alignment on grid 5862
# Running alignment on grid 5863
# Running alignment on grid 5864
# Running alignment on grid 5865
# Running alignment on grid 5866
# Running alignment on grid 5867
# Running alignment on grid 5868
# Running alignment on grid 5869
# Running alignment on grid 5870
# Running alignment on grid 5871
# Running alignment on grid 5872
# Running alignment on grid 5873
# Running alignment on grid 5874
# Running alignment on grid 5875
# Running alignment on grid 5876
# Running alignment on grid 5877
# Running alignment on grid 5878
# Running alignment on grid 5879
# Running alignment on grid 5880
# Running alignment on grid 5881
# Running alignment on grid 5882
# Running alignment on grid 5883
# Running alignment on grid 5884
# Running alignment on grid 5885
# Running alignment on grid 5886
# Running alignment on grid 5887
# Running alignment on grid 5888
# Running alignment on grid 5889
# Running alignment on grid 5890
# Running alignment on grid 5891
# Running alignment on grid 5892
# Running alignment on grid 5893
# Running alignment on grid 5894
# Running alignment on grid 5895
# Running alignment on grid 5896
# Running alignment on grid 5897
# Running alignment on grid 5898
# Running alignment on grid 5899
# Running alignment on grid 5900
# Running alignment on grid 5901
# Running alignment on grid 5902
# Running alignment on grid 5903
# Running alignment on grid 5904
# Running alignment on grid 5905
# Running alignment on grid 5906
# Running alignment on grid 5907
# Running alignment on grid 5908
# Running alignment on grid 5909
# Running alignment on grid 5910
# Running alignment on grid 5911
# Running alignment on grid 5912
# Running alignment on grid 5913
# Running alignment on grid 5914
# Running alignment on grid 5915
# Running alignment on grid 5916
# Running alignment on grid 5917
# Running alignment on grid 5918
# Running alignment on grid 5919
# Running alignment on grid 5920
# Running alignment on grid 5921
# Running alignment on grid 5922
# Running alignment on grid 5923
# Running alignment on grid 5924
# Running alignment on grid 5925
# Running alignment on grid 5926
# Running alignment on grid 5927
# Running alignment on grid 5928
# Running alignment on grid 5929
# Running alignment on grid 5930
# Running alignment on grid 5931
# Running alignment on grid 5932
# Running alignment on grid 5933
# Running alignment on grid 5934
# Running alignment on grid 5935
# Running alignment on grid 5936
# Running alignment on grid 5937
# Running alignment on grid 5938
# Running alignment on grid 5939
# Running alignment on grid 5940
# Running alignment on grid 5941
# Running alignment on grid 5942
# Running alignment on grid 5943
# Running alignment on grid 5944
# Running alignment on grid 5945
# Running alignment on grid 5946
# Running alignment on grid 5947
# Running alignment on grid 5948
# Running alignment on grid 5949
# Running alignment on grid 5950
# Running alignment on grid 5951
# Running alignment on grid 5952
# Running alignment on grid 5953
# Running alignment on grid 5954
# Running alignment on grid 5955
# Running alignment on grid 5956
# Running alignment on grid 5957
# Running alignment on grid 5958
# Running alignment on grid 5959
# Running alignment on grid 5960
# Running alignment on grid 5961
# Running alignment on grid 5962
# Running alignment on grid 5963
# Running alignment on grid 5964
# Running alignment on grid 5965
# Running alignment on grid 5966
# Running alignment on grid 5967
# Running alignment on grid 5968
# Running alignment on grid 5969
# Running alignment on grid 5970
# Running alignment on grid 5971
# Running alignment on grid 5972
# Running alignment on grid 5973
# Running alignment on grid 5974
# Running alignment on grid 5975
# Running alignment on grid 5976
# Running alignment on grid 5977
# Running alignment on grid 5978
# Running alignment on grid 5979
# Running alignment on grid 5980
# Running alignment on grid 5981
# Running alignment on grid 5982
# Running alignment on grid 5983
# Running alignment on grid 5984
# Running alignment on grid 5985
# Running alignment on grid 5986
# Running alignment on grid 5987
# Running alignment on grid 5988
# Running alignment on grid 5989
# Running alignment on grid 5990
# Running alignment on grid 5991
# Running alignment on grid 5992
# Running alignment on grid 5993
# Running alignment on grid 5994
# Running alignment on grid 5995
# Running alignment on grid 5996
# Running alignment on grid 5997
# Running alignment on grid 5998
# Running alignment on grid 5999
# Running alignment on grid 6000
# Running alignment on grid 6001
# Running alignment on grid 6002
# Running alignment on grid 6003
# Running alignment on grid 6004
# Running alignment on grid 6005
# Running alignment on grid 6006
# Running alignment on grid 6007
# Running alignment on grid 6008
# Running alignment on grid 6009
# Running alignment on grid 6010
# Running alignment on grid 6011
# Running alignment on grid 6012
# Running alignment on grid 6013
# Running alignment on grid 6014
# Running alignment on grid 6015
# Running alignment on grid 6016
# Running alignment on grid 6017
# Running alignment on grid 6018
# Running alignment on grid 6019
# Running alignment on grid 6020
# Running alignment on grid 6021
# Running alignment on grid 6022
# Running alignment on grid 6023
# Running alignment on grid 6024
# Running alignment on grid 6025
# Running alignment on grid 6026
# Running alignment on grid 6027
# Running alignment on grid 6028
# Running alignment on grid 6029
# Running alignment on grid 6030
# Running alignment on grid 6031
# Running alignment on grid 6032
# Running alignment on grid 6033
# Running alignment on grid 6034
# Running alignment on grid 6035
# Running alignment on grid 6036
# Running alignment on grid 6037
# Running alignment on grid 6038
# Running alignment on grid 6039
# Running alignment on grid 6040
# Running alignment on grid 6041
# Running alignment on grid 6042
# Running alignment on grid 6043
# Running alignment on grid 6044
# Running alignment on grid 6045
# Running alignment on grid 6046
# Running alignment on grid 6047
# Running alignment on grid 6048
# Running alignment on grid 6049
# Running alignment on grid 6050
# Running alignment on grid 6051
# Running alignment on grid 6052
# Running alignment on grid 6053
# Running alignment on grid 6054
# Running alignment on grid 6055
# Running alignment on grid 6056
# Running alignment on grid 6057
# Running alignment on grid 6058
# Running alignment on grid 6059
# Running alignment on grid 6060
# Running alignment on grid 6061
# Running alignment on grid 6062
# Running alignment on grid 6063
# Running alignment on grid 6064
# Running alignment on grid 6065
# Running alignment on grid 6066
# Running alignment on grid 6067
# Running alignment on grid 6068
# Running alignment on grid 6069
# Running alignment on grid 6070
# Running alignment on grid 6071
# Running alignment on grid 6072
# Running alignment on grid 6073
# Running alignment on grid 6074
# Running alignment on grid 6075
# Running alignment on grid 6076
# Running alignment on grid 6077
# Running alignment on grid 6078
# Running alignment on grid 6079
# Running alignment on grid 6080
# Running alignment on grid 6081
# Running alignment on grid 6082
# Running alignment on grid 6083
# Running alignment on grid 6084
# Running alignment on grid 6085
# Running alignment on grid 6086
# Running alignment on grid 6087
# Running alignment on grid 6088
# Running alignment on grid 6089
# Running alignment on grid 6090
# Running alignment on grid 6091
# Running alignment on grid 6092
# Running alignment on grid 6093
# Running alignment on grid 6094
# Running alignment on grid 6095
# Running alignment on grid 6096
# Running alignment on grid 6097
# Running alignment on grid 6098
# Running alignment on grid 6099
# Running alignment on grid 6100
# Running alignment on grid 6101
# Running alignment on grid 6102
# Running alignment on grid 6103
# Running alignment on grid 6104
# Running alignment on grid 6105
# Running alignment on grid 6106
# Running alignment on grid 6107
# Running alignment on grid 6108
# Running alignment on grid 6109
# Running alignment on grid 6110
# Running alignment on grid 6111
# Running alignment on grid 6112
# Running alignment on grid 6113
# Running alignment on grid 6114
# Running alignment on grid 6115
# Running alignment on grid 6116
# Running alignment on grid 6117
# Running alignment on grid 6118
# Running alignment on grid 6119
# Running alignment on grid 6120
# Running alignment on grid 6121
# Running alignment on grid 6122
# Running alignment on grid 6123
# Running alignment on grid 6124
# Running alignment on grid 6125
# Running alignment on grid 6126
# Running alignment on grid 6127
# Running alignment on grid 6128
# Running alignment on grid 6129
# Running alignment on grid 6130
# Running alignment on grid 6131
# Running alignment on grid 6132
# Running alignment on grid 6133
# Running alignment on grid 6134
# Running alignment on grid 6135
# Running alignment on grid 6136
# Running alignment on grid 6137
# Running alignment on grid 6138
# Running alignment on grid 6139
# Running alignment on grid 6140
# Running alignment on grid 6141
# Running alignment on grid 6142
# Running alignment on grid 6143
# Running alignment on grid 6144
# Running alignment on grid 6145
# Running alignment on grid 6146
# Running alignment on grid 6147
# Running alignment on grid 6148
# Running alignment on grid 6149
# Running alignment on grid 6150
# Running alignment on grid 6151
# Running alignment on grid 6152
# Running alignment on grid 6153
# Running alignment on grid 6154
# Running alignment on grid 6155
# Running alignment on grid 6156
# Running alignment on grid 6157
# Running alignment on grid 6158
# Running alignment on grid 6159
# Running alignment on grid 6160
# Running alignment on grid 6161
# Running alignment on grid 6162
# Running alignment on grid 6163
# Running alignment on grid 6164
# Running alignment on grid 6165
# Running alignment on grid 6166
# Running alignment on grid 6167
# Running alignment on grid 6168
# Running alignment on grid 6169
# Running alignment on grid 6170
# Running alignment on grid 6171
# Running alignment on grid 6172
# Running alignment on grid 6173
# Running alignment on grid 6174
# Running alignment on grid 6175
# Running alignment on grid 6176
# Running alignment on grid 6177
# Running alignment on grid 6178
# Running alignment on grid 6179
# Running alignment on grid 6180
# Running alignment on grid 6181
# Running alignment on grid 6182
# Running alignment on grid 6183
# Running alignment on grid 6184
# Running alignment on grid 6185
# Running alignment on grid 6186
# Running alignment on grid 6187
# Running alignment on grid 6188
# Running alignment on grid 6189
# Running alignment on grid 6190
# Running alignment on grid 6191
# Running alignment on grid 6192
# Running alignment on grid 6193
# Running alignment on grid 6194
# Running alignment on grid 6195
# Running alignment on grid 6196
# Running alignment on grid 6197
# Running alignment on grid 6198
# Running alignment on grid 6199
# Running alignment on grid 6200
# Running alignment on grid 6201
# Running alignment on grid 6202
# Running alignment on grid 6203
# Running alignment on grid 6204
# Running alignment on grid 6205
# Running alignment on grid 6206
# Running alignment on grid 6207
# Running alignment on grid 6208
# Running alignment on grid 6209
# Running alignment on grid 6210
# Running alignment on grid 6211
# Running alignment on grid 6212
# Running alignment on grid 6213
# Running alignment on grid 6214
# Running alignment on grid 6215
# Running alignment on grid 6216
# Running alignment on grid 6217
# Running alignment on grid 6218
# Running alignment on grid 6219
# Running alignment on grid 6220
# Running alignment on grid 6221
# Running alignment on grid 6222
# Running alignment on grid 6223
# Running alignment on grid 6224
# Running alignment on grid 6225
# Running alignment on grid 6226
# Running alignment on grid 6227
# Running alignment on grid 6228
# Running alignment on grid 6229
# Running alignment on grid 6230
# Running alignment on grid 6231
# Running alignment on grid 6232
# Running alignment on grid 6233
# Running alignment on grid 6234
# Running alignment on grid 6235
# Running alignment on grid 6236
# Running alignment on grid 6237
# Running alignment on grid 6238
# Running alignment on grid 6239
# Running alignment on grid 6240
# Running alignment on grid 6241
# Running alignment on grid 6242
# Running alignment on grid 6243
# Running alignment on grid 6244
# Running alignment on grid 6245
# Running alignment on grid 6246
# Running alignment on grid 6247
# Running alignment on grid 6248
# Running alignment on grid 6249
# Running alignment on grid 6250
# Running alignment on grid 6251
# Running alignment on grid 6252
# Running alignment on grid 6253
# Running alignment on grid 6254
# Running alignment on grid 6255
# Running alignment on grid 6256
# Running alignment on grid 6257
# Running alignment on grid 6258
# Running alignment on grid 6259
# Running alignment on grid 6260
# Running alignment on grid 6261
# Running alignment on grid 6262
# Running alignment on grid 6263
# Running alignment on grid 6264
# Running alignment on grid 6265
# Running alignment on grid 6266
# Running alignment on grid 6267
# Running alignment on grid 6268
# Running alignment on grid 6269
# Running alignment on grid 6270
# Running alignment on grid 6271
# Running alignment on grid 6272
# Running alignment on grid 6273
# Running alignment on grid 6274
# Running alignment on grid 6275
# Running alignment on grid 6276
# Running alignment on grid 6277
# Running alignment on grid 6278
# Running alignment on grid 6279
# Running alignment on grid 6280
# Running alignment on grid 6281
# Running alignment on grid 6282
# Running alignment on grid 6283
# Running alignment on grid 6284
# Running alignment on grid 6285
# Running alignment on grid 6286
# Running alignment on grid 6287
# Running alignment on grid 6288
# Running alignment on grid 6289
# Running alignment on grid 6290
# Running alignment on grid 6291
# Running alignment on grid 6292
# Running alignment on grid 6293
# Running alignment on grid 6294
# Running alignment on grid 6295
# Running alignment on grid 6296
# Running alignment on grid 6297
# Running alignment on grid 6298
# Running alignment on grid 6299
# Running alignment on grid 6300
# Running alignment on grid 6301
# Running alignment on grid 6302
# Running alignment on grid 6303
# Running alignment on grid 6304
# Running alignment on grid 6305
# Running alignment on grid 6306
# Running alignment on grid 6307
# Running alignment on grid 6308
# Running alignment on grid 6309
# Running alignment on grid 6310
# Running alignment on grid 6311
# Running alignment on grid 6312
# Running alignment on grid 6313
# Running alignment on grid 6314
# Running alignment on grid 6315
# Running alignment on grid 6316
# Running alignment on grid 6317
# Running alignment on grid 6318
# Running alignment on grid 6319
# Running alignment on grid 6320
# Running alignment on grid 6321
# Running alignment on grid 6322
# Running alignment on grid 6323
# Running alignment on grid 6324
# Running alignment on grid 6325
# Running alignment on grid 6326
# Running alignment on grid 6327
# Running alignment on grid 6328
# Running alignment on grid 6329
# Running alignment on grid 6330
# Running alignment on grid 6331
# Running alignment on grid 6332
# Running alignment on grid 6333
# Running alignment on grid 6334
# Running alignment on grid 6335
# Running alignment on grid 6336
# Running alignment on grid 6337
# Running alignment on grid 6338
# Running alignment on grid 6339

# %%
import pandas as pd
df = pd.DataFrame(results)

print("Mean Acc FGW:", df["ACC_FGW"].mean())
print("Mean Acc TOAST:", df["ACC_TOAST"].mean())
print("Mean Acc DeST-OT:", df["ACC_DEST"].mean())
# Out:
# Mean Acc FGW: 0.07568333342545562
# Mean Acc TOAST: 0.561647929082766
# Mean Acc DeST-OT: 0.03103752708360186
